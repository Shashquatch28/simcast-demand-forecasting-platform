# %%
# Imports
import pandas as pd

# %%
df = pd.read_csv("../data/raw/train.csv")

print("Data Shape:", df.shape)
print("\n------------------------------\n")
df.head()
# Out:
# Data Shape: (913000, 4)
#
# ------------------------------
#          date  store  item  sales
# 0  2013-01-01      1     1     13
# 1  2013-01-02      1     1     11
# 2  2013-01-03      1     1     14
# 3  2013-01-04      1     1     13
# 4  2013-01-05      1     1     10
